# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('food_prices_dza.xlsx')

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame
# Out:
#             date  country   admin1  admin2   admin3   latitude  longitude  \
# 0     2015-04-15  Algeria    Alger     NaN    Hydra  36.752887   3.042048
# 1     2015-04-15  Algeria    Alger     NaN    Hydra  36.752887   3.042048
# 2     2015-04-15  Algeria    Alger     NaN    Hydra  36.752887   3.042048
# 3     2015-04-15  Algeria    Alger     NaN    Hydra  36.752887   3.042048
# 4     2015-04-15  Algeria    Alger     NaN    Hydra  36.752887   3.042048
# ...          ...      ...      ...     ...      ...        ...        ...
# 1488  2021-05-15  Algeria  Tindouf     NaN  Tindouf  27.676101  -8.127653
# 1489  2021-05-15  Algeria  Tindouf     NaN  Tindouf  27.676101  -8.127653
# 1490  2021-05-15  Algeria  Tindouf     NaN  Tindouf  27.676101  -8.127653
# 1491  2021-05-15  Algeria  Tindouf     NaN  Tindouf  27.676101  -8.127653
# 1492  2021-05-15  Algeria  Tindouf     NaN  Tindouf  27.676101  -8.127653
#
#                    category      commodity    unit pricetype currency  price  \
# ...

# %%
dataFrame.shape
# Out:
# (1493, 16)

# %%
dataFrame.dtypes
# Out:
# date          object
# country       object
# admin1        object
# admin2       float64
# admin3        object
# latitude     float64
# longitude    float64
# category      object
# commodity     object
# unit          object
# pricetype     object
# currency      object
# price        float64
# usdprice     float64
# Year           int64
# Month        float64
# dtype: object

# %%
sb.heatmap(data=dataFrame.isna())
# Out:
# <AxesSubplot:>

# %%
df = dataFrame
df = df.dropna(axis=1,how='all')

# %%
sb.heatmap(data=df.isna())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#             date  country   admin1   admin3   latitude  longitude  \
# 0     2015-04-15  Algeria    Alger    Hydra  36.752887   3.042048
# 1     2015-04-15  Algeria    Alger    Hydra  36.752887   3.042048
# 2     2015-04-15  Algeria    Alger    Hydra  36.752887   3.042048
# 3     2015-04-15  Algeria    Alger    Hydra  36.752887   3.042048
# 4     2015-04-15  Algeria    Alger    Hydra  36.752887   3.042048
# ...          ...      ...      ...      ...        ...        ...
# 1488  2021-05-15  Algeria  Tindouf  Tindouf  27.676101  -8.127653
# 1489  2021-05-15  Algeria  Tindouf  Tindouf  27.676101  -8.127653
# 1490  2021-05-15  Algeria  Tindouf  Tindouf  27.676101  -8.127653
# 1491  2021-05-15  Algeria  Tindouf  Tindouf  27.676101  -8.127653
# 1492  2021-05-15  Algeria  Tindouf  Tindouf  27.676101  -8.127653
#
#                    category      commodity    unit pricetype currency  price  \
# 0        cereals and tubers          Bread    Unit    actual      DZD   10.0
# ...

# %%
df = df.drop(columns=['country', 'currency', 'pricetype'])

# %%
df
# Out:
#             date   admin1   admin3   latitude  longitude  \
# 0     2015-04-15    Alger    Hydra  36.752887   3.042048
# 1     2015-04-15    Alger    Hydra  36.752887   3.042048
# 2     2015-04-15    Alger    Hydra  36.752887   3.042048
# 3     2015-04-15    Alger    Hydra  36.752887   3.042048
# 4     2015-04-15    Alger    Hydra  36.752887   3.042048
# ...          ...      ...      ...        ...        ...
# 1488  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1489  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1490  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1491  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1492  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
#
#                    category      commodity    unit  price  usdprice  Year  \
# 0        cereals and tubers          Bread    Unit   10.0      0.07  2015
# 1        cereals and tubers          Pasta   500 G   60.0      0.43  2015
# ...

# %%
df.isnull()
# Out:
#        date  admin1  admin3  latitude  longitude  category  commodity   unit  \
# 0     False   False   False     False      False     False      False  False
# 1     False   False   False     False      False     False      False  False
# 2     False   False   False     False      False     False      False  False
# 3     False   False   False     False      False     False      False  False
# 4     False   False   False     False      False     False      False  False
# ...     ...     ...     ...       ...        ...       ...        ...    ...
# 1488  False   False   False     False      False     False      False  False
# 1489  False   False   False     False      False     False      False  False
# 1490  False   False   False     False      False     False      False  False
# 1491  False   False   False     False      False     False      False  False
# 1492  False   False   False     False      False     False      False  False
#
#       price  usdprice   Year  Month
# ...

# %%
df = df.fillna(5)
df
# Out:
#             date   admin1   admin3   latitude  longitude  \
# 0     2015-04-15    Alger    Hydra  36.752887   3.042048
# 1     2015-04-15    Alger    Hydra  36.752887   3.042048
# 2     2015-04-15    Alger    Hydra  36.752887   3.042048
# 3     2015-04-15    Alger    Hydra  36.752887   3.042048
# 4     2015-04-15    Alger    Hydra  36.752887   3.042048
# ...          ...      ...      ...        ...        ...
# 1488  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1489  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1490  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1491  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1492  2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
#
#                    category      commodity    unit  price  usdprice  Year  \
# 0        cereals and tubers          Bread    Unit   10.0      0.07  2015
# 1        cereals and tubers          Pasta   500 G   60.0      0.43  2015
# ...

# %%
df['date'].value_counts()
# Out:
# 2016-08-15             132
# 2016-07-15             131
# 2016-09-15             127
# 2016-10-15             127
# 2016-02-15             111
# 2016-03-15             107
# 2015-04-15              76
# 2015-12-15              74
# 2015-11-15              73
# 2015-10-15              72
# 2015-05-15              72
# 2016-01-15              70
# 2015-07-15              68
# 2015-08-15              67
# 2015-06-15              67
# 2015-09-15              66
# 2021-05-15              50
# 2016-01-15 00:00:00      2
#                          1
# Name: date, dtype: int64

# %%
text_empty = df['date'].str.len() > -1
text_empty
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1488    True
# 1489    True
# 1490    True
# 1491    True
# 1492    True
# Name: date, Length: 1493, dtype: bool

# %%
df.loc[text_empty == False].index
# Out:
# Int64Index([636, 637], dtype='int64')

# %%
df['date'][635]= '2015-12-15'
# Out:
# <ipython-input-204-9268c5019f9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'][635]= '2015-12-15'

# %%
df['date'][635]
# Out:
# '2015-12-15'

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0      2015-04-15
# 1      2015-04-15
# 2      2015-04-15
# 3      2015-04-15
# 4      2015-04-15
#           ...
# 1488   2021-05-15
# 1489   2021-05-15
# 1490   2021-05-15
# 1491   2021-05-15
# 1492   2021-05-15
# Name: date, Length: 1493, dtype: datetime64[ns]

# %%
df = df.rename(columns={'admin1':'State', 'admin3':'City', 'price':"DZDPrice"})

# %%
df.describe()
# Out:
#           latitude    longitude     DZDPrice     usdprice         Year  \
# count  1493.000000  1493.000000  1493.000000  1493.000000  1493.000000
# mean     29.049174    -5.813241   167.447354     1.203295  2015.741460
# std       3.569110     4.110959   151.740076     1.090434     1.094161
# min      26.827448    -8.127653     4.000000     0.030000  2015.000000
# 25%      27.492310    -8.014000    60.000000     0.430000  2015.000000
# 50%      27.631001    -7.828405   110.000000     0.790000  2016.000000
# 75%      27.740000    -6.869948   230.000000     1.650000  2016.000000
# max      36.752887     3.042048   700.000000     5.030000  2021.000000
#
#              Month
# count  1493.000000
# mean      6.929672
# std       3.075852
# min       1.000000
# 25%       5.000000
# 50%       7.000000
# 75%       9.000000
# max      12.000000

# %%
plt.scatter(df['date'], df['DZDPrice'])

# %%
sb.boxplot(x=df['Year'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df
# Out:
#            date    State     City   latitude  longitude  \
# 0    2015-04-15    Alger    Hydra  36.752887   3.042048
# 1    2015-04-15    Alger    Hydra  36.752887   3.042048
# 2    2015-04-15    Alger    Hydra  36.752887   3.042048
# 3    2015-04-15    Alger    Hydra  36.752887   3.042048
# 4    2015-04-15    Alger    Hydra  36.752887   3.042048
# ...         ...      ...      ...        ...        ...
# 1488 2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1489 2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1490 2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1491 2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
# 1492 2021-05-15  Tindouf  Tindouf  27.676101  -8.127653
#
#                    category      commodity    unit  DZDPrice  usdprice  Year  \
# 0        cereals and tubers          Bread    Unit      10.0      0.07  2015
# 1        cereals and tubers          Pasta   500 G      60.0      0.43  2015
# ...

# %%
 new_df = df[df['date'].dt.year != 2021].copy()
new_df
# Out:
#            date    State     City   latitude  longitude  \
# 0    2015-04-15    Alger    Hydra  36.752887   3.042048
# 1    2015-04-15    Alger    Hydra  36.752887   3.042048
# 2    2015-04-15    Alger    Hydra  36.752887   3.042048
# 3    2015-04-15    Alger    Hydra  36.752887   3.042048
# 4    2015-04-15    Alger    Hydra  36.752887   3.042048
# ...         ...      ...      ...        ...        ...
# 1438 2016-10-15  Tindouf  Tindouf  27.676101  -8.127653
# 1439 2016-10-15  Tindouf  Tindouf  27.676101  -8.127653
# 1440 2016-10-15  Tindouf  Tindouf  27.676101  -8.127653
# 1441 2016-10-15  Tindouf  Tindouf  27.676101  -8.127653
# 1442 2016-10-15  Tindouf  Tindouf  27.676101  -8.127653
#
#                    category commodity    unit  DZDPrice  usdprice  Year  Month
# 0        cereals and tubers     Bread    Unit      10.0      0.07  2015    4.0
# 1        cereals and tubers     Pasta   500 G      60.0      0.43  2015    4.0
# ...

# %%
new_df.to_excel('newData.xlsx')

# %%
new_df['City'].value_counts()
# Out:
# Tindouf     302
# Samara      294
# Dakhla      292
# Hydra       262
# Layoun      115
# Auserd      106
# Boujdour     72
# Name: City, dtype: int64

# %%
new_df['category'].value_counts()
# Out:
# cereals and tubers       316
# meat, fish and eggs      304
# vegetables and fruits    205
# pulses and nuts          160
# miscellaneous food       148
# non-food                 145
# milk and dairy           144
# oil and fats              21
# Name: category, dtype: int64

# %%
ricePrice = new_df['DZDPrice'].where(new_df['commodity']=='Rice')
breadPrice = new_df['DZDPrice'].where(new_df['commodity']=='Bread')
sugarPrice = new_df['DZDPrice'].where(new_df['commodity']=='Sugar')

# %%
ricePrice = ricePrice.dropna()
breadPrice = breadPrice.dropna()
sugarPrice = sugarPrice.dropna()

# %%
plt.figure(figsize=(10,5))

plt.plot(df['date'].where(new_df['commodity']=='Rice').dropna(),ricePrice,c='blue', label='Rice Price')
plt.plot(df['date'].where(new_df['commodity']=='Bread').dropna(),breadPrice,c='red',label='Bread Price')
plt.plot(df['date'].where(new_df['commodity']=='Sugar').dropna(),sugarPrice,c='green',label='Sugar Price')
plt.legend()
plt.show()

# %%
new_df1 = new_df.groupby(['category', 'commodity','Year']).std()
new_df1
# Out:
#                                                    latitude  longitude  \
# category              commodity              Year
# cereals and tubers    Bread                  2015  4.149622   4.700987
#                                              2016  3.589306   4.167022
#                       Pasta                  2015  4.149622   4.700987
#                                              2016  3.448900   4.018077
#                       Potatoes               2015  4.149622   4.700987
#                                              2016  3.448900   4.018077
#                       Rice                   2015  4.149622   4.700987
#                                              2016  3.448900   4.018077
# meat, fish and eggs   Eggs                   2015  4.149622   4.700987
#                                              2016  3.448900   4.018077
#                       Fish (canned)          2015  4.149622   4.700987
# ...

# %%
test_df = new_df.copy()
eggs = new_df['commodity'].where(new_df['commodity'] == 'Eggs').dropna()
hydra = new_df['City'].where(new_df['City'] == 'Hydra').dropna()
test_df['commodity'] = eggs
test_df = test_df.dropna()
test_df['City'] = hydra
test_df = test_df.dropna()
eggs_price = test_df.groupby(['commodity','Month']).std()
eggs_price
# Out:
#                  latitude  longitude    DZDPrice  usdprice      Year
# commodity Month
# Eggs      1.0         NaN        NaN         NaN       NaN       NaN
#           2.0         NaN        NaN         NaN       NaN       NaN
#           3.0         NaN        NaN         NaN       NaN       NaN
#           4.0         NaN        NaN         NaN       NaN       NaN
#           5.0         NaN        NaN         NaN       NaN       NaN
#           6.0         NaN        NaN         NaN       NaN       NaN
#           7.0         0.0        0.0   84.852814  0.608112  0.707107
#           8.0         0.0        0.0  106.066017  0.763675  0.707107
#           9.0         0.0        0.0   56.568542  0.410122  0.707107
#           10.0        0.0        0.0   45.961941  0.325269  0.707107
#           11.0        NaN        NaN         NaN       NaN       NaN
#           12.0        NaN        NaN         NaN       NaN       NaN

# %%
tindouf_df = new_df.copy()
tea = new_df['commodity'].where(new_df['commodity'] == 'Tea (sahm)').dropna()
tindouf = new_df['State'].where(new_df['State'] == 'Tindouf').dropna()
tindouf_df['commodity'] = tea
tindouf_df['State'] = tindouf
tindouf_df.dropna()
tea_Price = tindouf_df.groupby(['commodity','State','Month']).std()
tea_Price
# Out:
#                           latitude  longitude   DZDPrice  usdprice  Year
# commodity  State   Month
# Tea (sahm) Tindouf 1.0    0.446474   0.657015   0.000000  0.000000   0.0
#                    2.0    0.372362   0.502146   0.000000  0.000000   0.0
#                    3.0    0.372362   0.502146   0.000000  0.000000   0.0
#                    4.0    0.446474   0.657015   5.773503  0.040415   0.0
#                    5.0    0.446474   0.657015   0.000000  0.000000   0.0
#                    6.0    0.446474   0.657015   0.000000  0.000000   0.0
#                    7.0    0.353188   0.499417  15.000000  0.110000   0.5
#                    8.0    0.353188   0.499417  10.000000  0.070000   0.5
#                    9.0    0.353188   0.499417  10.000000  0.070000   0.5
#                    10.0   0.353188   0.499417   5.000000  0.035000   0.5
#                    11.0   0.446474   0.657015   0.000000  0.000000   0.0
# ...

# %%
year_price = new_df.copy()
Y2015 = new_df['Year'].where(new_df['Year'] == 2015).dropna()
tindouf = new_df['State'].where(new_df['State'] == 'Tindouf').dropna()
year_price['Year'] = Y2015
tindouf_df['State'] = tindouf
year_price = year_price.dropna()
year_price = year_price.sort_values(by='DZDPrice', ascending=False)
year_price = year_price.drop(['date', 'State', 'City', 'latitude', 'longitude', 'unit','Month'], axis=1)

prices=year_price.groupby(['commodity'])['DZDPrice'].max().sort_values()
prices
# Out:
# commodity
# Bread                      10.0
# Fuel (petrol-gasoline)     50.0
# Fuel (diesel)              50.0
# Pasta                      60.0
# Fish (canned)              80.0
# Milk                      100.0
# Rice                      100.0
# Sugar                     100.0
# Onions                    120.0
# Oil                       140.0
# Potatoes                  140.0
# Carrots                   140.0
# Tea (sahm)                150.0
# Tomatoes                  150.0
# Milk (camel)              170.0
# Cheese (dry)              220.0
# Lentils                   240.0
# Oranges                   250.0
# Beans (white)             280.0
# Bananas                   280.0
# Apples                    300.0
# Eggs                      360.0
# Meat (chicken)            450.0
# Tea                       509.0
# Meat (camel)              700.0
# Name: DZDPrice, dtype: float64

# %%
price_plot = new_df[['DZDPrice', 'usdprice']].copy()
x = price_plot['DZDPrice']
y = price_plot['usdprice']
plt.figure()
plt.scatter(x,y)
plt.plot(x,y)
